# %%
# %run ../Functionality.py

# %%
Missing
# Out:
#          2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# Ticker
# ATEN    False  False  False  False  False  False  False  False  False  False
# ATVI    False  False  False  False  False  False  False  False  False  False
# ADBE    False  False  False  False  False  False  False  False  False  False
# AMD     False  False  False  False  False  False  False  False  False  False
# ABNB    False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# OSTK    False  False  False  False  False  False  False  False  False  False
# MELI    False  False  False  False  False  False  False  False  False  False
# CVNA    False  False  False  False  False  False  False  False  False  False
# MVIS    False  False  False  False  False  False  False  False  False  False
# SPSC    False  False  False   True  False  False  False  False  False  False
#
# [151 rows x 10 columns]

# %%
Missing.apply(sum,axis=1).sort_values().tail(25)
# Out:
# Ticker
# HPQ     1
# STMP    1
# VRSN    1
# AUD     1
# MSI     1
# SIRI    1
# NFLX    1
# IRBT    1
# WU      1
# PAYC    1
# WDAY    2
# ZEN     2
# LYV     2
# GME     2
# PRTS    3
# NTAP    3
# SNPS    3
# EFX     3
# WWE     3
# EQIX    4
# MSFT    5
# INTC    5
# EXPE    5
# TRIP    7
# FIS     8
# dtype: int64

# %%
Missing.loc['GME']
# Out:
# 2011     True
# 2012     True
# 2013    False
# 2014    False
# 2015    False
# 2016    False
# 2017    False
# 2018    False
# 2019    False
# 2020    False
# Name: GME, dtype: bool

# %%
ticker='GME'
method='Text2'
cik=Filed.loc[ticker].CIK
base_path=samples_path+ticker+'/'
files=get_10Ks_names(cik)
for i in range(8,10):
    y=str(2020-i)
    print(y,end='...')
    path=base_path+y+'.txt'
    try:
        txt=get_Risk_Disc(cik,files[i],method)
        with open(path,'w') as f:f.write(txt)
        with open(log_paths[method][0],'a') as f: f: f.write(ticker+'--'+y+'\n')
    except:
        with open(log_paths[method][1],'a') as f: f: f.write(ticker+'--'+y+'\n')
        pass
    finally:
        pass
print('COMPLETE')
# Out:
# 2012...2011...COMPLETE

# %%
update_filings()
